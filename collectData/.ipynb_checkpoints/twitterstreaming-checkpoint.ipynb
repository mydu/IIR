# %% [markdown]
# ### Import the necessary methods from tweepy library :

# %%
from tweepy.streaming import StreamListener
from tweepy import OAuthHandler
from tweepy import Stream
import tweepy
import json
import csv

# %%
consumer_key = "SK5OItiv1BWWPka2yDLzRzijw"
consumer_secret = "maZDODe1X7UqpeF2DiHZY3SEHkKEO0q1qNrmCESmksPrC5DB9H"
access_token = "264393411-5pf360OD2MrAdNy4ttsiYI0CkbzMdUp3ubhKSWJK"
access_token_secret = "9ySEEIhpyHx4snHLHD3tMnDPyj7TipDknss1N8CBQtVyF"

# %%
auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)
api = tweepy.API(auth,wait_on_rate_limit=True,wait_on_rate_limit_notify=True)

# %%
# places=api.trends_available()
# for i in places:
#     if i["placeType"]["name"]=="Country":
#         print i['name'].encode('ascii', 'ignore')+","+i['country'].encode('ascii', 'ignore')+","+str(i['woeid'])
# Out:
# United Arab Emirates,United Arab Emirates,23424738
# Algeria,Algeria,23424740
# Argentina,Argentina,23424747
# Australia,Australia,23424748
# Austria,Austria,23424750
# Bahrain,Bahrain,23424753
# Belgium,Belgium,23424757
# Belarus,Belarus,23424765
# Brazil,Brazil,23424768
# Canada,Canada,23424775
# Chile,Chile,23424782
# Colombia,Colombia,23424787
# Denmark,Denmark,23424796
# Dominican Republic,Dominican Republic,23424800
# Ecuador,Ecuador,23424801
# Egypt,Egypt,23424802
# Ireland,Ireland,23424803
# France,France,23424819
# Ghana,Ghana,23424824
# Germany,Germany,23424829
# Greece,Greece,23424833
# Guatemala,Guatemala,23424834
# Indonesia,Indonesia,23424846
# India,India,23424848
# Israel,Israel,23424852
# Italy,Italy,23424853
# Japan,Japan,23424856
# Jordan,Jordan,23424860
# Kenya,Kenya,23424863
# Korea,Korea,23424868
# Kuwait,Kuwait,23424870
# Lebanon,Lebanon,23424873
# Latvia,Latvia,23424874
# Oman,Oman,23424898
# Mexico,Mexico,23424900
# Malaysia,Malaysia,23424901
# Nigeria,Nigeria,23424908
# Netherlands,Netherlands,23424909
# Norway,Norway,23424910
# New Zealand,New Zealand,23424916
# Peru,Peru,23424919
# Pakistan,Pakistan,23424922
# Poland,Poland,23424923
# Panama,Panama,23424924
# Portugal,Portugal,23424925
# Qatar,Qatar,23424930
# Philippines,Philippines,23424934
# Puerto Rico,Puerto Rico,23424935
# Russia,Russia,23424936
# Saudi Arabia,Saudi Arabia,23424938
# South Africa,South Africa,23424942
# Singapore,Singapore,23424948
# Spain,Spain,23424950
# Sweden,Sweden,23424954
# Switzerland,Switzerland,23424957
# Thailand,Thailand,23424960
# Turkey,Turkey,23424969
# United Kingdom,United Kingdom,23424975
# Ukraine,Ukraine,23424976
# United States,United States,23424977
# Venezuela,Venezuela,23424982
# Vietnam,Vietnam,23424984

# %%
# europe_woeid=[23424757,23424796,23424803,23424819,23424829,23424833,23424853,23424909,23424910,23424925,23424950,23424954,23424957,23424969,23424975]
# namerica_woeid=[23424775,23424977]

# %%
# trends_list=[]
# for i in namerica_woeid:
#     trends=api.trends_place(i) 
#     for i in trends[0]["trends"]:
#         print i['name'].encode('ascii', 'ignore')
#         trends_list.append(i['name'])
# Out:
# #TwitterAwakens
# Bill Bennett
# Greinke
# #AmazingRace
# Robert Loggia
# #ThroneSpeech
# #BlueNeighbourhood
# #UndateableLive
# DBacks
# Huskies
# Max Domi
# Sting
# Mike Smith
# After 40
# FOTL
# Scott Weiland
# San Bernardino
# Ross Atkins
# #MuslimApartment
# #SharkTank
# #TotallyAbsurdWars
# #Bellator147
# #ALDUBRendezvous
# #Remparts
# #TheExperience10
# #ANTM
# #RAM48
# #HometownHockey
# #Knicks
# #DALvsEDM
# #TowTrucks
# #MarliesLive
# #marcommtour
# #Olympiques
# #BOSvsCGY
# #ToyDriveLive
# #Reign
# #KathNielChristmasLoveDuets
# #NeptonesOniTunes
# #CGS55
# #NationalCookieDay
# #TheWiz
# #CBCSOTS
# #CBCOpenHouse
# #TheGameAwards
# #FridayFeeling
# #Packers
# #nlwx
# #PurposeInTO
# #Lions
# Greinke
# #TwitterAwakens
# #BlueNeighbourhood
# Robert Loggia
# #RDFamilyHoliday
# #UndateableLive
# Dodgers
# #ANTM
# Diamondbacks
# Joe Johnson
# Moments
# Cueto
# Bronco Mendenhall
# Aaron Hernandez
# John Lackey
# The Knicks
# Evander Kane
# Bud Weisser
# Manvel
# Dean Wade
# Kyle Porter
# Parkview Baptist
# Lance Thomas
# Jeff Choate
# Jared Dudley
# End 1
# Tom Holmoe
# #MuslimApartment
# #TotallyAbsurdWars
# #AmazingRace
# #21ProjectQandA
# #NASCARawards
# #GirlMeetsTheNewYear
# #MarriageBootCamp
# #Grimm
# #KIISJingleBall
# #Bellator147
# #MasterChefJunior
# #DrKen
# #Cygnus
# #TashfeenMalik
# #Reign
# #femsplainactually
# #BeemieAwards
# #NYKvsBKN
# #WizSuns
# #Saban15
# #FuegoFriday
# #CabFrancDay
# #engagechat

# %%
trends_list=[]
writer_trends=csv.writer(open('Trends1206.csv','a'))
# writer.writerow(["createdAt","trend"])
trends=api.trends_place(23424977)
create=trends[0]["created_at"]
print create
# for placeid in namerica_woeid:
#     trends=api.trends_place(placeid)
for i in trends[0]["trends"]:
    print i["name"]
    writer_trends.writerow([create,i["name"]])
    trends_list.append(i['name'])
# Out:
# 2015-12-06T14:07:05Z
# Ayesha Curry
# #YouAintNoMuslimBruv
# #6DCambiemosVzla
# #InappropriateChanukahGifts
# Happy Hanukkah
# #LosDeChavezAVotar
# #hacklearning
# Good Sunday
# Vamos Venezuela
# Jim Ross
# B-52
# Aden
# St. Nicholas
# Let Math Save Our Democracy
# Dear Obama
# Victory Tour
# 13th Amendment
# Go Bills
# Justin and Selena
# Jerry Falwell Jr.
# Brashton
# Snapchat - SelfieSnaps
# #YouCanDoItLiam
# #RnRSA
# #WetMusic
# #ZaynsStill1DAF
# #USWNT
# #HorseAroundWithAFilmOrSong
# #sunchat
# #Reporte6D
# #Parlamentarias2015
# #PoliticsNation
# #JingleAllTheWay5k
# #wcs2015
# #ThingsIShouldntAdmit
# #PreMoney
# #FelizDomingo
# #IBYE
# #ThinkBIGSundayWithMarsha
# #IndigenousRising
# #EleccionesVIVOplay
# #thisweek
# #IoTWF2015
# #HOUvsBUF
# #JetUp
# #NYJvsNYG
# #CINvsCLE
# #aftALLin
# #LindaStasiHotTakes
# #6DNTN24

# %% [markdown]
# ### Variables that contains the user credentials to access Twitter API :

# %%
GEOBOX_WORLD = [-180,-90,180,90]
GEOBOX_PARIS = [2.225193,48.815573,2.469921,48.902145]
GEOBOX_FRANCE=[-5.14,41.34,9.56,51.09]
GEOBOX_EUROPE =[-31.5,34.5,74.4,82.2]
GEOBOX_NAmerica=[-169.72,25.05,-48.6,71.16]

# %% [markdown]
# ### This is a basic listener that just prints received tweets to stdout :

# %%
writer=csv.writer(open('NorthAmerica_Trends.csv','a'))
# writer.writerow(["time","text","hashtag","place"])
class StdOutListener(StreamListener):
    def on_data(self, data):
        trend_flag=False
        try:
            tweet = json.loads(data)
#             if any([item in hashtag_list for item in trends_list])==True:
#             if(len(tweet['entities']['hashtags'])>0):
#                 hashtag_list=[i["text"].encode('ascii', 'ignore') for i in tweet['entities']['hashtags']]
#                 if any([item in hashtag_list for item in trends_list]):
            time=tweet["created_at"]
            text=tweet["text"].encode('ascii', 'ignore')
            hashtag=" ".join([i["text"].encode('ascii', 'ignore') for i in tweet['entities']['hashtags']])
            location=tweet["user"]["location"].encode('ascii', 'ignore') if tweet["user"]["location"]!=None else "NA"
            place=tweet['place']['full_name'].encode('ascii', 'ignore') if tweet['place']!=None else "NA"
#             place=tweet['place']['full_name'].encode('ascii', 'ignore')
#             geobox=tweet['place']['bounding_box']['coordinates']
            writer.writerow([time,text,hashtag,place])
            # writer.writerow([status["created_at"], status["text"].encode('ascii', 'ignore')])
            print tweet["created_at"]
            # print status['text'].encode('ascii', 'ignore')
            return True
        except BaseException as e:
            print("Error on_data: %s" % str(e))
            pass
        return True
 
    def on_error(self, status):
        print(status)
        return True


if __name__ == '__main__':

    #This handles Twitter authetification and the connection to Twitter Streaming API
    l = StdOutListener()
    auth = OAuthHandler(consumer_key, consumer_secret)
    auth.set_access_token(access_token, access_token_secret)
    stream = Stream(auth, l)
    stream.filter(track=trends_list,languages = ['en'],stall_warnings=True)
#     stream.filter(locations=GEOBOX_NAmerica,languages = ['en'],stall_warnings=True)
# Out:
# Sun Dec 06 12:29:32 +0000 2015
# Sun Dec 06 12:29:32 +0000 2015
# Sun Dec 06 12:29:32 +0000 2015
# Sun Dec 06 12:29:32 +0000 2015
# Sun Dec 06 12:29:32 +0000 2015
# Sun Dec 06 12:29:32 +0000 2015
# Sun Dec 06 12:29:32 +0000 2015
# Sun Dec 06 12:29:32 +0000 2015
# Sun Dec 06 12:29:32 +0000 2015
# Sun Dec 06 12:29:32 +0000 2015
# Sun Dec 06 12:29:32 +0000 2015
# Sun Dec 06 12:29:33 +0000 2015
# Sun Dec 06 12:29:33 +0000 2015
# Sun Dec 06 12:29:33 +0000 2015
# Sun Dec 06 12:29:33 +0000 2015
# Sun Dec 06 12:29:33 +0000 2015
# Sun Dec 06 12:29:33 +0000 2015
# Sun Dec 06 12:29:33 +0000 2015
# Sun Dec 06 12:29:33 +0000 2015
# Sun Dec 06 12:29:33 +0000 2015
# Sun Dec 06 12:29:33 +0000 2015
# Sun Dec 06 12:29:33 +0000 2015
# Sun Dec 06 12:29:33 +0000 2015
# Sun Dec 06 12:29:33 +0000 2015
# Sun Dec 06 12:29:33 +0000 2015
# Sun Dec 06 12:29:33 +0000 2015
# Sun Dec 06 12:29:33 +0000 2015
# Sun Dec 06 12:29:33 +0000 2015
# Sun Dec 06 12:29:34 +0000 2015
# Sun Dec 06 12:29:34 +0000 2015
# Sun Dec 06 12:29:34 +0000 2015
# Sun Dec 06 12:29:34 +0000 2015
# Sun Dec 06 12:29:34 +0000 2015
# Sun Dec 06 12:29:34 +0000 2015
# Sun Dec 06 12:29:34 +0000 2015
# Sun Dec 06 12:29:34 +0000 2015
# Sun Dec 06 12:29:34 +0000 2015
# Sun Dec 06 12:29:34 +0000 2015
# Sun Dec 06 12:29:34 +0000 2015
# Sun Dec 06 12:29:34 +0000 2015
# Sun Dec 06 12:29:34 +0000 2015
# Sun Dec 06 12:29:34 +0000 2015
# Sun Dec 06 12:29:34 +0000 2015
# Sun Dec 06 12:29:34 +0000 2015
# Sun Dec 06 12:29:34 +0000 2015
# Sun Dec 06 12:29:34 +0000 2015
# Sun Dec 06 12:29:34 +0000 2015
# Sun Dec 06 12:29:34 +0000 2015
# Sun Dec 06 12:29:34 +0000 2015
# Sun Dec 06 12:29:34 +0000 2015
# Sun Dec 06 12:29:34 +0000 2015
# Sun Dec 06 12:29:34 +0000 2015
# Sun Dec 06 12:29:34 +0000 2015
# Sun Dec 06 12:29:34 +0000 2015
# Sun Dec 06 12:29:34 +0000 2015
# Sun Dec 06 12:29:34 +0000 2015
# Sun Dec 06 12:29:34 +0000 2015
# Sun Dec 06 12:29:34 +0000 2015
# Sun Dec 06 12:29:34 +0000 2015
# Sun Dec 06 12:29:34 +0000 2015
# Sun Dec 06 12:29:35 +0000 2015
# Sun Dec 06 12:29:35 +0000 2015
# Sun Dec 06 12:29:35 +0000 2015
# Sun Dec 06 12:29:35 +0000 2015
# Sun Dec 06 12:29:34 +0000 2015
# Sun Dec 06 12:29:35 +0000 2015
# Sun Dec 06 12:29:36 +0000 2015
# Sun Dec 06 12:29:36 +0000 2015
# Sun Dec 06 12:29:36 +0000 2015
# Sun Dec 06 12:29:36 +0000 2015
# Sun Dec 06 12:29:36 +0000 2015
# Sun Dec 06 12:29:36 +0000 2015
# Sun Dec 06 12:29:36 +0000 2015
# Sun Dec 06 12:29:36 +0000 2015
# Sun Dec 06 12:29:36 +0000 2015
# Sun Dec 06 12:29:36 +0000 2015
# Sun Dec 06 12:29:36 +0000 2015
# Sun Dec 06 12:29:37 +0000 2015
# Sun Dec 06 12:29:37 +0000 2015
# Sun Dec 06 12:29:37 +0000 2015
# Sun Dec 06 12:29:37 +0000 2015
# Sun Dec 06 12:29:37 +0000 2015
# Sun Dec 06 12:29:37 +0000 2015
# Sun Dec 06 12:29:37 +0000 2015
# Sun Dec 06 12:29:37 +0000 2015
# Sun Dec 06 12:29:37 +0000 2015
# Sun Dec 06 12:29:37 +0000 2015
# Sun Dec 06 12:29:37 +0000 2015
# Sun Dec 06 12:29:37 +0000 2015
# Sun Dec 06 12:29:37 +0000 2015
# Sun Dec 06 12:29:37 +0000 2015
# Sun Dec 06 12:29:37 +0000 2015
# Sun Dec 06 12:29:37 +0000 2015
# Sun Dec 06 12:29:37 +0000 2015
# Sun Dec 06 12:29:37 +0000 2015
# Sun Dec 06 12:29:37 +0000 2015
# Sun Dec 06 12:29:37 +0000 2015
# Sun Dec 06 12:29:38 +0000 2015
# Sun Dec 06 12:29:38 +0000 2015
# Sun Dec 06 12:29:38 +0000 2015
# Sun Dec 06 12:29:38 +0000 2015
# Sun Dec 06 12:29:38 +0000 2015
# Sun Dec 06 12:29:38 +0000 2015
# Sun Dec 06 12:29:38 +0000 2015
# Sun Dec 06 12:29:38 +0000 2015
# Sun Dec 06 12:29:38 +0000 2015
# Sun Dec 06 12:29:38 +0000 2015
# Sun Dec 06 12:29:38 +0000 2015
# Sun Dec 06 12:29:38 +0000 2015
# Sun Dec 06 12:29:38 +0000 2015
# Sun Dec 06 12:29:38 +0000 2015
# Sun Dec 06 12:29:38 +0000 2015
# Sun Dec 06 12:29:38 +0000 2015
# Sun Dec 06 12:29:38 +0000 2015
# Sun Dec 06 12:29:38 +0000 2015
# Sun Dec 06 12:29:38 +0000 2015
# Sun Dec 06 12:29:39 +0000 2015
# Sun Dec 06 12:29:39 +0000 2015
# Sun Dec 06 12:29:38 +0000 2015
# Sun Dec 06 12:29:39 +0000 2015
# Sun Dec 06 12:29:39 +0000 2015
# Sun Dec 06 12:29:39 +0000 2015
# Sun Dec 06 12:29:39 +0000 2015
# Sun Dec 06 12:29:39 +0000 2015
# Sun Dec 06 12:29:39 +0000 2015
# Sun Dec 06 12:29:39 +0000 2015
# Sun Dec 06 12:29:39 +0000 2015
# Sun Dec 06 12:29:39 +0000 2015
# Sun Dec 06 12:29:39 +0000 2015
# Sun Dec 06 12:29:39 +0000 2015
# Sun Dec 06 12:29:39 +0000 2015
# Sun Dec 06 12:29:40 +0000 2015
# Sun Dec 06 12:29:40 +0000 2015
# Sun Dec 06 12:29:40 +0000 2015
# Sun Dec 06 12:29:40 +0000 2015
# Sun Dec 06 12:29:40 +0000 2015
# Sun Dec 06 12:29:40 +0000 2015
# Sun Dec 06 12:29:40 +0000 2015
# Sun Dec 06 12:29:40 +0000 2015
# Sun Dec 06 12:29:40 +0000 2015
# Sun Dec 06 12:29:40 +0000 2015
# Sun Dec 06 12:29:40 +0000 2015
# Sun Dec 06 12:29:40 +0000 2015
# Sun Dec 06 12:29:40 +0000 2015
# Sun Dec 06 12:29:41 +0000 2015
# Sun Dec 06 12:29:41 +0000 2015
# Sun Dec 06 12:29:41 +0000 2015
# Sun Dec 06 12:29:41 +0000 2015
# Sun Dec 06 12:29:41 +0000 2015
# Sun Dec 06 12:29:41 +0000 2015
# Sun Dec 06 12:29:41 +0000 2015
# Sun Dec 06 12:29:41 +0000 2015
# Sun Dec 06 12:29:41 +0000 2015
# Sun Dec 06 12:29:41 +0000 2015
# Sun Dec 06 12:29:41 +0000 2015
# Sun Dec 06 12:29:41 +0000 2015
# Sun Dec 06 12:29:41 +0000 2015
# Sun Dec 06 12:29:41 +0000 2015
# Sun Dec 06 12:29:41 +0000 2015
# Sun Dec 06 12:29:41 +0000 2015
# Sun Dec 06 12:29:41 +0000 2015
# Sun Dec 06 12:29:42 +0000 2015
# Sun Dec 06 12:29:42 +0000 2015
# Sun Dec 06 12:29:42 +0000 2015
# Sun Dec 06 12:29:42 +0000 2015
# Sun Dec 06 12:29:42 +0000 2015
# Sun Dec 06 12:29:42 +0000 2015
# Sun Dec 06 12:29:42 +0000 2015
# Sun Dec 06 12:29:42 +0000 2015
# Sun Dec 06 12:29:42 +0000 2015
# Sun Dec 06 12:29:42 +0000 2015
# Sun Dec 06 12:29:42 +0000 2015
# Sun Dec 06 12:29:42 +0000 2015
# Sun Dec 06 12:29:42 +0000 2015
# Sun Dec 06 12:29:43 +0000 2015
# Sun Dec 06 12:29:43 +0000 2015
# Sun Dec 06 12:29:43 +0000 2015
# Sun Dec 06 12:29:43 +0000 2015
# Sun Dec 06 12:29:43 +0000 2015
# Sun Dec 06 12:29:43 +0000 2015
# Sun Dec 06 12:29:43 +0000 2015
# Sun Dec 06 12:29:43 +0000 2015
# Sun Dec 06 12:29:43 +0000 2015
# Sun Dec 06 12:29:43 +0000 2015
# Sun Dec 06 12:29:43 +0000 2015
# Sun Dec 06 12:29:43 +0000 2015
# Sun Dec 06 12:29:43 +0000 2015
# Sun Dec 06 12:29:43 +0000 2015
# Sun Dec 06 12:29:44 +0000 2015
# Sun Dec 06 12:29:44 +0000 2015
# Sun Dec 06 12:29:43 +0000 2015
# Sun Dec 06 12:29:44 +0000 2015
# Sun Dec 06 12:29:43 +0000 2015
# Sun Dec 06 12:29:44 +0000 2015
# Sun Dec 06 12:29:44 +0000 2015
# Sun Dec 06 12:29:44 +0000 2015
# Sun Dec 06 12:29:44 +0000 2015

# %%
print type(str('asdfa'))
print type(None)
